# %% [markdown]
# # 遍历北京地铁
#
# ## 加载库并设置中文字体

# %%
# -*-coding:utf-8-*- 
# %matplotlib inline
import json
import random
import time
import math
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
# 设置中文字体（plt默认不支持中文）
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 获取数据
#
# 国内baidu和高德都有地图数据api（具体api参数使用可见相应地图官网）
#
# 百度api http://map.baidu.com/?qt=bsi&c=131&t=1557640374739
#
# 高德api http://map.amap.com/service/subway?_1557640374739&srhdata=1100_drw_beijing.json
#
# 这里baidu地图数据与高德地图数据均已保存在本地，可直接读取（此处以高德地图数据示例）

# %% [markdown]
# ### 经纬度距离转换

# %%
def distance(lon1, lat1, lon2, lat2):
    """
    通过经纬度计算距离
    """
    # return np.sqrt(np.square(x_2 - x_1) + np.square(y_2 - y_1))
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    r = 6371.393 # 地球平均半径（千米）
    return c * r * 1000

# %% [markdown]
# ### 解析百度地图数据

# %%
with open("./dat/subway_bj_baidu.json","r") as load_f:
    subway_dic = json.load(load_f)

# %%
# 拆分为序列
subway_line = []
for i in subway_dic["content"]:
    site_line = i["stops"]
    for j in range(len(site_line)-1):
        dis = distance(site_line[j]["x"], site_line[j]["y"], 
                       site_line[j + 1]["x"], site_line[j + 1]["y"])
        edge = (site_line[j]["name"], site_line[j + 1]["name"], dis)
        subway_line.append(edge)

# %% [markdown]
# ### 解析高德地图数据

# %%
with open("./dat/subway_bj_amap.json","r") as load_f:
    subway_dic = json.load(load_f)

# %%
subway_line = []
k = 1
for i in subway_dic["l"]:
    site_line = i["st"]
    for j in range(len(site_line)-1):
        lng1, lat1 = map(float, site_line[j]["sl"].split(","))
        lng2, lat2 = map(float, site_line[j + 1]["sl"].split(","))
        dis = distance(lng1, lat1, lng2, lat2)
        edge = (site_line[j]["n"], site_line[j + 1]["n"], dis)
        subway_line.append(edge)

# %%
subway_line
# Out:
# [('金安桥', '四道桥', 2626.0025093304116),
#  ('四道桥', '桥户营', 808.5481551958499),
#  ('桥户营', '上岸', 861.7094592137288),
#  ('上岸', '栗园庄', 1044.3223017705857),
#  ('栗园庄', '小园', 956.2650802792436),
#  ('小园', '石厂', 1209.871129096451),
#  ('苹果园', '古城', 2411.4083228554928),
#  ('古城', '八角游乐园', 1906.2186163036702),
#  ('八角游乐园', '八宝山', 1984.4394579069644),
#  ('八宝山', '玉泉路', 1444.99704849566),
#  ('玉泉路', '五棵松', 1799.7647876420103),
#  ('五棵松', '万寿路', 1772.3819923710817),
#  ('万寿路', '公主坟', 1292.6489339152822),
#  ('公主坟', '军事博物馆', 984.3858549043264),
#  ('军事博物馆', '木樨地', 1375.400358943996),
#  ('木樨地', '南礼士路', 1279.6171615865194),
#  ('南礼士路', '复兴门', 365.34579395761557),
#  ('复兴门', '西单', 1467.773278401595),
#  ('西单', '天安门西', 1467.7204329657716),
#  ('天安门西', '天安门东', 848.4093796644286),
#  ('天安门东', '王府井', 883.8687262914634),
#  ('王府井', '东单', 590.024368172228),
#  ('东单', '建国门', 1478.031495113334),
#  ('建国门', '永安里', 1253.1470257320439),
#  ('永安里', '国贸', 970.3300791012629),
#  ('国贸', '大望路', 1192.7082086692105),
#  ('大望路', '四惠', 1678.883885698566),
#  ('四惠', '四惠东', 1723.9616702010005),
#  ('积水潭', '鼓楼大街', 1760.7561317556292),
#  ('鼓楼大街', '安定门', 1233.258550336533),
#  ('安定门', '雍和宫', 752.8613625247445),
#  ('雍和宫', '东直门', 1815.6431639603454),
#  ('东直门', '东四十条', 882.2702114888017),
#  ('东四十条', '朝阳门', 1035.1136995159222),
#  ('朝阳门', '建国门', 1782.0565552606713),
#  ('建国门', '北京站', 825.297198667952),
#  ('北京站', '崇文门', 972.7514723640546),
#  ('崇文门', '前门', 1637.0537663892192),
#  ('前门', '和平门', 1171.181700345175),
#  ('和平门', '宣武门', 844.9564416605269),
#  ('宣武门', '长椿街', 935.647900952962),
#  ('长椿街', '复兴门', 1029.8023379263752),
#  ('复兴门', '阜成门', 1830.0624726885026),
#  ('阜成门', '车公庄', 978.8688371861759),
#  ('车公庄', '西直门', 902.789881063723),
#  ('天宫院', '生物医药基地', 1803.9968443355604),
#  ('生物医药基地', '义和庄', 2886.0426104150706),
#  ('义和庄', '黄村火车站', 1650.3609369200485),
#  ('黄村火车站', '黄村西大街', 978.9108147069464),
#  ('黄村西大街', '清源路', 1218.25735219231),
#  ('清源路', '枣园', 1193.9323044718387),
#  ('枣园', '高米店南', 1116.6398206728009),
#  ('高米店南', '高米店北', 1120.6507615348821),
#  ('高米店北', '西红门', 1816.2335539213163),
#  ('西红门', '新宫', 4042.3174660310906),
#  ('新宫', '公益西桥', 2656.097833810274),
#  ('公益西桥', '角门西', 1080.7577064551078),
#  ('角门西', '马家堡', 807.4071873969672),
#  ('马家堡', '北京南站', 1475.841376853923),
#  ('北京南站', '陶然亭', 1544.9292528075252),
#  ('陶然亭', '菜市口', 1203.8758674418968),
#  ('菜市口', '宣武门', 1164.210013301693),
#  ('宣武门', '西单', 847.3867050082189),
#  ('西单', '灵境胡同', 948.847557269785),
#  ('灵境胡同', '西四', 922.9832006406383),
#  ('西四', '平安里', 1084.115323536054),
#  ('平安里', '新街口', 866.1590471587098),
#  ('新街口', '西直门', 1050.2766033809332),
#  ('西直门', '动物园', 1419.564990331149),
#  ('动物园', '国家图书馆', 1298.1283123793714),
#  ('国家图书馆', '魏公村', 1653.2261686173492),
#  ('魏公村', '人民大学', 1018.913300583134),
#  ('人民大学', '海淀黄庄', 1056.2168693253734),
#  ('海淀黄庄', '中关村', 893.9588136318573),
#  ('中关村', '北京大学东门', 915.7394413198956),
#  ('北京大学东门', '圆明园', 958.3854392597194),
#  ('圆明园', '西苑', 1649.636107091082),
#  ('西苑', '北宫门', 1218.8025448037172),
#  ('北宫门', '安河桥北', 1273.6163006558902),
#  ('宋家庄', '刘家窑', 1403.3055931870238),
#  ('刘家窑', '蒲黄榆', 911.0422656709595),
#  ('蒲黄榆', '天坛东门', 1899.471822699264),
#  ('天坛东门', '磁器口', 1182.7526422441767),
#  ('磁器口', '崇文门', 910.4884073397402),
#  ('崇文门', '东单', 816.1689021161467),
#  ('东单', '灯市口', 979.0479371245173),
#  ('灯市口', '东四', 807.3702671580048),
#  ('东四', '张自忠路', 1025.9054385412355),
#  ('张自忠路', '北新桥', 799.8771232114472),
#  ('北新桥', '雍和宫', 951.3508227943819),
#  ('雍和宫', '和平里北街', 1052.2088639247784),
#  ('和平里北街', '和平西桥', 1074.2662124564622),
#  ('和平西桥', '惠新西街南口', 972.0645031769538),
#  ('惠新西街南口', '惠新西街北口', 1192.3161985266056),
#  ('惠新西街北口', '大屯路东', 1780.0328991452495),
#  ('大屯路东', '北苑路北', 2958.0330571913296),
#  ('北苑路北', '立水桥南', 1317.0632682055152),
#  ('立水桥南', '立水桥', 1245.1448544064115),
#  ('立水桥', '天通苑南', 1493.2297980930969),
#  ('天通苑南', '天通苑', 974.6081310141699),
#  ('天通苑', '天通苑北', 939.274417196287),
#  ('潞城', '东夏园', 1160.1104547374969),
#  ('东夏园', '郝家府', 1366.9567601624206),
#  ('郝家府', '北运河东', 918.7826843458527),
#  ('北运河东', '北运河西', 1595.2864266806544),
#  ('北运河西', '通州北关', 2855.3151549916893),
#  ('通州北关', '物资学院路', 2104.1213302933575),
#  ('物资学院路', '草房', 2041.101956999777),
#  ('草房', '常营', 1358.6203905646594),
#  ('常营', '黄渠', 1837.284533450236),
#  ('黄渠', '褡裢坡', 1220.096177449873),
#  ('褡裢坡', '青年路', 3969.417499320077),
#  ('青年路', '十里堡', 1312.008054684485),
#  ('十里堡', '金台路', 2041.474651591272),
#  ('金台路', '呼家楼', 1407.0903946494225),
#  ('呼家楼', '东大桥', 850.0692588143638),
#  ('东大桥', '朝阳门', 1464.834452061095),
#  ('朝阳门', '东四', 1457.5860680103015),
#  ('东四', '南锣鼓巷', 1548.3303511996057),
#  ('南锣鼓巷', '北海北', 1482.022129520939),
#  ('北海北', '平安里', 1191.7111532491376),
#  ('平安里', '车公庄', 1589.0899097281683),
#  ('车公庄', '车公庄西', 876.1802334035788),
#  ('车公庄西', '白石桥南', 1570.3443259150665),
#  ('白石桥南', '花园桥', 1281.032609150693),
#  ('花园桥', '慈寿寺', 1301.5548132307142),
#  ('慈寿寺', '海淀五路居', 1616.4467785367094),
#  ('海淀五路居', '田村', 2042.7924798963954),
#  ('田村', '廖公庄', 2208.809314268643),
#  ('廖公庄', '西黄村', 1741.0543038719766),
#  ('西黄村', '杨庄', 1815.811061009995),
#  ('杨庄', '金安桥', 2086.487446519106),
#  ('焦化厂', '双合', 1004.1196916919371),
#  ('双合', '垡头', 1286.8523873136444),
#  ('垡头', '欢乐谷景区', 1191.3185243917999),
#  ('欢乐谷景区', '南楼梓庄', 901.9182963633608),
#  ('南楼梓庄', '化工', 1436.5082848824654),
#  ('化工', '百子湾', 750.6667258815709),
#  ('百子湾', '大郊亭', 842.0787247594119),
#  ('大郊亭', '九龙山', 788.3557632513617),
#  ('九龙山', '广渠门外', 2534.1405760438734),
#  ('广渠门外', '广渠门内', 1290.096875735553),
#  ('广渠门内', '磁器口', 1190.3858913297238),
#  ('磁器口', '桥湾', 980.3807811491062),
#  ('桥湾', '珠市口', 898.6627495524775),
#  ('珠市口', '虎坊桥', 1169.4237629290176),
#  ('虎坊桥', '菜市口', 868.0808625397565),
#  ('菜市口', '广安门内', 1381.110915717573),
#  ('广安门内', '达官营', 1859.3988405749535),
#  ('达官营', '湾子', 742.5187981081039),
#  ('湾子', '北京西站', 768.1907035527231),
#  ('中国美术馆', '南锣鼓巷', 1260.9580181687522),
#  ('南锣鼓巷', '什刹海', 796.6590270327366),
#  ('什刹海', '鼓楼大街', 1283.4895037409676),
#  ('鼓楼大街', '安德里北街', 925.3588195846178),
#  ('安德里北街', '安华桥', 1255.0512072005793),
#  ('安华桥', '北土城', 940.0351396955612),
#  ('北土城', '奥体中心', 988.6085678226635),
#  ('奥体中心', '奥林匹克公园', 1828.3378007191418),
#  ('奥林匹克公园', '森林公园南门', 883.0793292644227),
#  ('森林公园南门', '林萃桥', 2122.286116119724),
#  ('林萃桥', '永泰庄', 2356.916217936956),
#  ('永泰庄', '西小口', 1047.2069827249375),
#  ('西小口', '育新', 1509.4703923213824),
#  ('育新', '霍营', 1715.5673258092302),
#  ('霍营', '回龙观东大街', 1062.0654323372753),
#  ('回龙观东大街', '平西府', 1499.750478238334),
#  ('平西府', '育知路', 2016.758430123632),
#  ('育知路', '朱辛庄', 2149.085165119146),
#  ('珠市口', '天桥', 1040.6969720010409),
#  ('天桥', '永定门外', 1611.7334430525996),
#  ('永定门外', '木樨园', 909.7371612790115),
#  ('木樨园', '海户屯', 830.1690565366157),
#  ('海户屯', '大红门南', 1679.2368423433663),
#  ('大红门南', '和义', 2434.345106727046),
#  ('和义', '东高地', 1254.4057638752658),
#  ('东高地', '火箭万源', 1015.81337546273),
#  ('火箭万源', '五福堂', 1646.5390983038906),
#  ('五福堂', '德茂', 2042.9992789204055),
#  ('德茂', '瀛海', 1476.0975492727653),
#  ('郭公庄', '丰台科技园', 1278.3536091733627),
#  ('丰台科技园', '科怡路', 806.1758260656541),
#  ('科怡路', '丰台南路', 887.53488197379),
#  ('丰台南路', '丰台东大街', 1649.56652653887),
#  ('丰台东大街', '七里庄', 1297.3666860435833),
#  ('七里庄', '六里桥', 1664.4963894877005),
#  ('六里桥', '六里桥东', 1286.0959958791352),
#  ('六里桥东', '北京西站', 1012.3999649650706),
#  ('北京西站', '军事博物馆', 1414.1913617696136),
#  ('军事博物馆', '白堆子', 1859.8351089251985),
#  ('白堆子', '白石桥南', 1023.5251224898185),
#  ('白石桥南', '国家图书馆', 1123.0258161399433),
#  ('巴沟', '苏州街', 1086.4080330149422),
#  ('苏州街', '海淀黄庄', 957.951568352137),
#  ('海淀黄庄', '知春里', 950.4672899144673),
#  ('知春里', '知春路', 958.8833017415869),
#  ('知春路', '西土城', 1204.7942552436537),
#  ('西土城', '牡丹园', 1341.8045022497477),
#  ('牡丹园', '健德门', 980.8258049712675),
#  ('健德门', '北土城', 1094.4517696123637),
#  ('北土城', '安贞门', 1002.2211571057995),
#  ('安贞门', '惠新西街南口', 987.119417072293),
#  ('惠新西街南口', '芍药居', 1567.0194538336816),
#  ('芍药居', '太阳宫', 1128.5220822673793),
#  ('太阳宫', '三元桥', 1484.007585764321),
#  ('三元桥', '亮马桥', 1405.5562350250216),
#  ('亮马桥', '农业展览馆', 897.5294533780002),
#  ('农业展览馆', '团结湖', 844.8288975002591),
#  ('团结湖', '呼家楼', 1157.7215948370895),
#  ('呼家楼', '金台夕照', 722.7790297524053),
#  ('金台夕照', '国贸', 860.0752306203916),
#  ('国贸', '双井', 1740.611625174576),
#  ('双井', '劲松', 1012.7992045735892),
#  ('劲松', '潘家园', 1001.3950900351962),
#  ('潘家园', '十里河', 1028.6179655743108),
#  ('十里河', '分钟寺', 1614.5985501654218),
#  ('分钟寺', '成寿寺', 895.4598915661268),
#  ('成寿寺', '宋家庄', 1636.0913237313043),
#  ('宋家庄', '石榴庄', 1217.9256312751227),
#  ('石榴庄', '大红门', 1277.6315658025735),
#  ('大红门', '角门东', 1153.3629633336134),
#  ('角门东', '角门西', 1240.1049530586304),
#  ('角门西', '草桥', 1687.6583410972833),
#  ('草桥', '纪家庙', 1545.5943454294847),
#  ('纪家庙', '首经贸', 1125.2181354028123),
#  ('首经贸', '丰台站', 1455.7772897366008),
#  ('丰台站', '泥洼', 997.9719143527354),
#  ('泥洼', '西局', 908.0206660749585),
#  ('西局', '六里桥', 1500.2599989354849),
#  ('六里桥', '莲花桥', 2063.10863718227),
#  ('莲花桥', '公主坟', 1068.3836046582514),
#  ('公主坟', '西钓鱼台', 2047.6266057586452),
#  ('西钓鱼台', '慈寿寺', 1110.6350484817106),
#  ('慈寿寺', '车道沟', 1635.7154986842727),
#  ('车道沟', '长春桥', 1179.7719961305136),
#  ('长春桥', '火器营', 935.6153180097748),
#  ('西直门', '大钟寺', 3035.9892843430225),
#  ('大钟寺', '知春路', 1182.3601884589689),
#  ('知春路', '五道口', 1835.4659484865315),
#  ('五道口', '上地', 4704.383471738008),
#  ('上地', '西二旗', 2521.8190269305815),
#  ('西二旗', '龙泽', 2277.8612041962656),
#  ('龙泽', '回龙观', 1420.0440411290288),
#  ('回龙观', '霍营', 2060.13723488756),
#  ('霍营', '立水桥', 4900.645484705816),
#  ('立水桥', '北苑', 2192.3195236665715),
#  ('北苑', '望京西', 5417.268108810679),
#  ('望京西', '芍药居', 2337.2105992450643),
#  ('芍药居', '光熙门', 1092.9534906787285),
#  ('光熙门', '柳芳', 1135.0304959541231),
#  ('柳芳', '东直门', 1857.3452836069368),
#  ('善各庄', '来广营', 1201.6177835415706),
#  ('来广营', '东湖渠', 1103.4737005846202),
#  ('东湖渠', '望京', 1361.657333661069),
#  ('望京', '阜通', 784.1790758064876),
#  ('阜通', '望京南', 1152.3159699663279),
#  ('望京南', '将台', 1646.4675578734023),
#  ('将台', '东风北桥', 1448.4897282773356),
#  ('东风北桥', '枣营', 1839.4018769159393),
#  ('枣营', '朝阳公园', 1217.054763018338),
#  ('朝阳公园', '金台路', 1105.0028711197665),
#  ('金台路', '大望路', 1709.549791312242),
#  ('大望路', '九龙山', 1693.5736395360518),
#  ('九龙山', '平乐园', 891.6207279034187),
#  ('平乐园', '北工大西门', 1093.11403394334),
#  ('北工大西门', '十里河', 1931.6368091552647),
#  ('十里河', '方庄', 1515.294248741255),
#  ('方庄', '蒲黄榆', 1410.6365352716684),
#  ('蒲黄榆', '景泰', 1084.1517182570158),
#  ('景泰', '永定门外', 1024.1385349963878),
#  ('永定门外', '北京南站', 1762.126365122135),
#  ('西局', '七里庄', 813.1436973488277),
#  ('七里庄', '大井', 1565.5408913718827),
#  ('大井', '郭庄子', 1963.003404086097),
#  ('郭庄子', '大瓦窑', 1229.3191875139605),
#  ('大瓦窑', '园博园', 3321.5359086711137),
#  ('园博园', '张郭庄', 1284.6264841874245),
#  ('俸伯', '顺义', 2373.2527315545804),
#  ('顺义', '石门', 1352.548141669147),
#  ('石门', '南法信', 2689.267126599907),
#  ('南法信', '后沙峪', 4171.414030745111),
#  ('后沙峪', '花梨坎', 3349.3387045919953),
#  ('花梨坎', '国展', 1615.6564446331827),
#  ('国展', '孙河', 3271.116328395722),
#  ('孙河', '马泉营', 2944.4079492139253),
#  ('马泉营', '崔各庄', 1562.7812017941626),
#  ('崔各庄', '望京东', 2171.1488393680756),
#  ('望京东', '望京', 1594.6950330883951),
#  ('望京', '望京西', 1692.1479055200602),
#  ('望京西', '关庄', 1721.7209506394083),
#  ('关庄', '大屯路东', 1194.478207783749),
#  ('大屯路东', '安立路', 823.2425515817034),
#  ('安立路', '奥林匹克公园', 1371.096539469562),
#  ('奥林匹克公园', '北沙滩', 2013.1720289112063),
#  ('北沙滩', '六道口', 1319.3887240528788),
#  ('六道口', '清华东路西口', 1119.77281330808),
#  ('北安河', '温阳路', 2632.758497065246),
#  ('温阳路', '稻香湖路', 2279.7890797702535),
#  ('稻香湖路', '屯佃', 2358.2977067944435),
#  ('屯佃', '永丰', 1962.91381270705),
#  ('永丰', '永丰南', 1080.4249715796655),
#  ('永丰南', '西北旺', 2052.187410139171),
#  ('西北旺', '马连洼', 2176.27153760303),
#  ('马连洼', '农大南路', 1500.5188690866125),
#  ('农大南路', '西苑', 2676.2752241413723),
#  ('四惠', '四惠东', 1723.9616702010005),
#  ('四惠东', '高碑店', 1348.2272511034762),
#  ('高碑店', '传媒大学', 1980.6304313184057),
#  ('传媒大学', '双桥', 1885.3307893183633),
#  ('双桥', '管庄', 1905.1265744334623),
#  ('管庄', '八里桥', 1708.866952054732),
#  ('八里桥', '通州北苑', 1605.8753601533851),
#  ('通州北苑', '果园', 1411.6048578466177),
#  ('果园', '九棵树', 994.5663780070407),
#  ('九棵树', '梨园', 1204.1498369534518),
#  ('梨园', '临河里', 1252.6609576320263),
#  ('临河里', '土桥', 755.9463084537269),
#  ('昌平西山口', '十三陵景区', 1156.0235516312785),
#  ('十三陵景区', '昌平', 3101.9109331100663),
#  ('昌平', '昌平东关', 2420.80900820437),
#  ('昌平东关', '北邵洼', 1689.0986967121778),
#  ('北邵洼', '南邵', 1681.6865628622154),
#  ('南邵', '沙河高教园', 4800.042058845851),
#  ('沙河高教园', '沙河', 1957.2240631963834),
#  ('沙河', '巩华城', 1980.7635815167373),
#  ('巩华城', '朱辛庄', 3400.508830570361),
#  ('朱辛庄', '生命科学园', 1964.663641045782),
#  ('生命科学园', '西二旗', 4755.484464137766),
#  ('阎村东', '苏庄', 2192.822981400581),
#  ('苏庄', '良乡南关', 1325.5423980780718),
#  ('良乡南关', '良乡大学城西', 1323.8406422662797),
#  ('良乡大学城西', '良乡大学城', 1732.7500018015278),
#  ('良乡大学城', '良乡大学城北', 956.6169021348151),
#  ('良乡大学城北', '广阳城', 2008.4283280745315),
#  ('广阳城', '篱笆房', 1464.3903133901042),
#  ('篱笆房', '长阳', 2016.0359041962238),
#  ('长阳', '稻田', 3488.6042839097067),
#  ('稻田', '大葆台', 6386.835215844905),
#  ('大葆台', '郭公庄', 1133.4583819125405),
#  ('T3航站楼', 'T2航站楼', 3541.4466079074464),
#  ('T2航站楼', '三元桥', 17474.897635569112),
#  ('三元桥', '东直门', 2853.1226735358464),
#  ('巴沟', '颐和园西门', 2895.789888792142),
#  ('颐和园西门', '茶棚', 1350.826200803373),
#  ('茶棚', '万安', 1389.7368452393455),
#  ('万安', '植物园', 1806.566306629828),
#  ('植物园', '香山', 884.3443780831394),
#  ('阎村东', '紫草坞', 1302.0739495258053),
#  ('紫草坞', '阎村', 1039.8194348337042),
#  ('阎村', '星城', 1643.1054444161757),
#  ('星城', '大石河东', 1883.8151120723167),
#  ('大石河东', '马各庄', 2063.2409945118457),
#  ('马各庄', '饶乐府', 985.1739017533329),
#  ('饶乐府', '房山城关', 1501.4054344317308),
#  ('房山城关', '燕山', 2047.7074626570645),
#  ('宋家庄', '肖村', 2142.0073524365193),
#  ('肖村', '小红门', 1160.1305265099459),
#  ('小红门', '旧宫', 2343.6021993708737),
#  ('旧宫', '亦庄桥', 1722.8401746450145),
#  ('亦庄桥', '亦庄文化园', 981.8719195114536),
#  ('亦庄文化园', '万源街', 1334.9975515345095),
#  ('万源街', '荣京东街', 1280.9738678392075),
#  ('荣京东街', '荣昌东街', 1355.5856879664937),
#  ('荣昌东街', '同济南路', 1904.5712108489038),
#  ('同济南路', '经海路', 2256.0821303954344),
#  ('经海路', '次渠南', 2065.3196431320866),
#  ('次渠南', '次渠', 1272.8076185806938),
#  ('次渠', '亦庄火车站', 1347.791615580616)]

# %% [markdown]
# ## 地图可视化
#
# 这里使用networkx绘制，如果痛殴坐标绘制，会更像实际看到的地图

# %%
plt.figure(figsize=(40, 40))
G = nx.Graph()
# l = [('你','我',5.0),('我','她',3.0),('你','她',1.0)]
G.add_weighted_edges_from(subway_line)
pos = nx.spring_layout(G)
nx.draw(G, pos, node_color='b', edge_color='r', 
        with_labels=True, font_size=30, node_size=10)
plt.show()

# %% [markdown]
# ## 两站之间的最短距离
#
# 采用Dijkstra算法，调用写好的dijkstra.DijkstraPath

# %%
from dijkstra import set_node_map
from dijkstra import DijkstraPath

# %%
# 将 x, y, w转换成矩阵
node, node_map = set_node_map(subway_line)

# 从西二旗到国贸
from_node = '西二旗'
to_node = '国贸'
djs = DijkstraPath(node, node_map)
path = djs.get_path(from_node, to_node)
print(path)
# Out:
# [('西二旗', 0), ('上地', 2521.8190269305815), ('五道口', 7226.202498668589), ('知春路', 9061.66844715512), ('大钟寺', 10244.02863561409), ('西直门', 13280.017919957112), ('新街口', 14330.294523338045), ('平安里', 15196.453570496755), ('北海北', 16388.164723745893), ('南锣鼓巷', 17870.18685326683), ('东四', 19418.517204466436), ('朝阳门', 20876.103272476736), ('东大桥', 22340.93772453783), ('呼家楼', 23191.006983352196), ('金台夕照', 23913.7860131046), ('国贸', 24773.86124372499)]
